# %% [markdown]
# # Test model: food classes (splits_new_v2) and non-food (food_not_food_ds)
#
# This notebook loads the fine-tuned EfficientNet-B3 checkpoint and runs inference on:
#
# - All food classes from `d:\\VSC FILES\\testtrain\\splits_new_v2` (test folders)
# - Non-food test images from `d:\\VSC FILES\\testtrain\\food_not_food_ds\\not_food\\test`
#
# Edit variables in the first code cell (ckpt_path, dataset roots, batch_size, threshold) before running.

# %%
# Section 1 — Environment & Dependencies

# (Optional) create a minimal requirements file. Edit as needed.
requirements = '''torch torchvision pillow torch-directml numpy'''
with open('requirements.txt', 'w') as f:
    f.write(requirements)

# Example: install packages (uncomment to run). On Windows with bash shell you can run these cells.
# %%bash
# pip install -r requirements.txt

print('requirements.txt written. Review and install packages if needed.')
# Out:
# requirements.txt written. Review and install packages if needed.

# %%
# Section 2 — Project structure (show top-level files/folders)
import os
root = r'd:\VSC FILES\testtrain'
print('Workspace root:', root)
for entry in sorted(os.listdir(root))[:80]:
    print(entry)

print('\nNotebook file: d:\\VSC FILES\\testtrain\\test_inference_nonfood_and_food.ipynb')
# Out:
# Workspace root: d:\VSC FILES\testtrain
# HF_ready.ipynb
# bad_images_by_class.json
# class_names.json
# export_to_onxx.ipynb
# fine_tune.ipynb
# fine_tune2.ipynb
# fine_tune2_.ipynb
# fine_tune2__.ipynb
# food-101-split
# food_not_food_ds
# hf_package
# inference_outputs
# model.onnx
# new_model.onnx
# new_splits
# new_train.ipynb
# nutrisight_model_training
# onxx
# openimages_downloads
# requirements.txt
# runs
# runs copy
# splits_new
# splits_new_v2
# test.ipynb
# test_inference_nonfood_and_food.ipynb
# test_model.ipynb
# test_model_finetune.ipynb
# test_model_finetune2.ipynb
# thesis-model-resnet50-20250824-230424
# thesis_datasets
# thesis_datasets_cleaned
# thesis_datasets_cleaned_split
# thesis_datasets_split
# train.ipynb
# train_efficientnet_b3_optimized.ipynb
# train_efficientnet_b3_optimized_food_not_food.ipynb
# train_efficientnet_b3_optimized_food_not_foodv2.ipynb
#
# Notebook file: d:\VSC FILES\testtrain\test_inference_nonfood_and_food.ipynb

# %%
# Section 3 — Import libraries
import os
import json
import torch
import torch.nn as nn
from torchvision import transforms, models
from PIL import Image
import numpy as np
from torch.utils.data import Dataset, DataLoader

# Optional import for DirectML
try:
    import torch_directml
    has_directml = True
except Exception:
    has_directml = False

print('torch:', torch.__version__)
print('torch_directml available:', has_directml)
# Out:
# torch: 2.4.1+cpu
# torch_directml available: True

# %%
# Section 4 — Device selection
try:
    if has_directml:
        dml = torch_directml.device()
        device = dml
    else:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
except Exception as e:
    print('Device selection error, falling back to CPU:', e)
    device = torch.device('cpu')

print('Using device:', device)
# Out:
# Using device: privateuseone:0

# %%
# Section 5 — Paths and checkpoint
# Edit these paths if needed
CKPT_PATH = r'D:\VSC FILES\testtrain\runs\efficientnet_b3_food_not_food-20251031-220332\best_efficientnet_b3.pth'
SPLITS_DIR = r'D:\VSC FILES\testtrain\splits_new_v2'
# Use the non-food root (contains train/val/test). We'll combine all folds.
NON_FOOD_DIR = r'D:\VSC FILES\testtrain\food_not_food_ds\not_food'
OUTPUT_DIR = r'd:\VSC FILES\testtrain\inference_outputs'
os.makedirs(OUTPUT_DIR, exist_ok=True)

print('Checkpoint exists?', os.path.exists(CKPT_PATH))

ckpt = torch.load(CKPT_PATH, map_location='cpu')
# Expected keys: 'classes', 'model_state', optionally 'mean','std','image_size'
classes = ckpt.get('classes') or ckpt.get('class_names')
if classes is None:
    raise RuntimeError('Checkpoint does not contain class list under "classes" or "class_names"')

mean = ckpt.get('mean', [0.485, 0.456, 0.406])
std = ckpt.get('std', [0.229, 0.224, 0.225])
image_size = ckpt.get('image_size', 300)  # default used during training
print('Loaded checkpoint. Model classes:', len(classes))
# Out:
# Checkpoint exists? True
# C:\Users\JP\AppData\Local\Temp\ipykernel_25968\602184936.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(CKPT_PATH, map_location='cpu')
# Loaded checkpoint. Model classes: 2

# %%
# Section 6 — Build model
num_classes = len(classes)
model = models.efficientnet_b3(weights=None)
# Replace classifier to match training code pattern
if hasattr(model, 'classifier'):
    # EfficientNet classifier is usually model.classifier[1]
    try:
        in_feats = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(in_feats, num_classes)
    except Exception:
        # fallback
        model.classifier = nn.Linear(model.classifier.in_features, num_classes)
else:
    # Generic fallback - replace last linear if found
    for name, module in reversed(list(model.named_modules())):
        if isinstance(module, nn.Linear):
            parent = model
            break

# Load weights (support different key names)
state_key = 'model_state' if 'model_state' in ckpt else 'state_dict' if 'state_dict' in ckpt else None
if state_key is None:
    raise RuntimeError('Checkpoint missing model_state/state_dict')
model.load_state_dict(ckpt[state_key])
model = model.to(device)
model.eval()
print('Model loaded and set to eval() on device', device)
# Out:
# Model loaded and set to eval() on device privateuseone:0

# %%
# Section 7 — Transforms and Datasets
from torchvision import transforms

eval_tfms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std),
])

# Helper to detect binary food/not_food checkpoint
def _detect_binary_food_ckpt(ckpt_classes):
    lower = [c.lower().replace(' ', '_').replace('-', '_') for c in ckpt_classes]
    food_idx = None
    not_food_idx = None
    for i, c in enumerate(lower):
        if c == 'food':
            food_idx = i
        if c in ('not_food', 'notfood', 'not_foods', 'not_food', 'nonfood', 'non_food', 'not food'):
            not_food_idx = i
    # also allow when only 'food' and 'not_food' are present in some variant
    if food_idx is not None and not_food_idx is not None:
        return True, food_idx, not_food_idx
    return False, food_idx, not_food_idx

class ImageFolderFlat(Dataset):
    """Collect images from <splits_root>/<class>/(train|val|test) and map labels to indices in ckpt['classes'] so indices align with model outputs.

    If the checkpoint is a binary food/not_food model, this class will treat all images under every class in `splits_root` as `food` (label index = index of 'food' in checkpoint)."""
    def __init__(self, splits_root, ckpt_classes, folds=None, transform=None):
        self.paths = []
        self.labels = []
        self.transform = transform
        self.ckpt_classes = list(ckpt_classes)
        # default folds to combine
        if folds is None:
            folds = ['train', 'val', 'test']
        # detect binary ckpt
        binary_mode, food_idx, not_food_idx = _detect_binary_food_ckpt(self.ckpt_classes)
        available = [d for d in os.listdir(splits_root) if os.path.isdir(os.path.join(splits_root, d))]
        available = set(available)
        skipped = []
        if binary_mode:
            # collect ALL images under every class folder and label them as 'food'
            for cls_dir_name in sorted(available):
                for fold in folds:
                    cls_dir = os.path.join(splits_root, cls_dir_name, fold)
                    if not os.path.isdir(cls_dir):
                        continue
                    for fn in os.listdir(cls_dir):
                        if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                            p = os.path.join(cls_dir, fn)
                            self.paths.append(p)
                            self.labels.append(food_idx)
            print(f"Binary checkpoint detected. Collected {len(self.paths)} images from splits and labeled them as 'food' (idx={food_idx}).")
        else:
            for cls_name in self.ckpt_classes:
                if cls_name not in available:
                    skipped.append(cls_name)
                    continue
                for fold in folds:
                    cls_dir = os.path.join(splits_root, cls_name, fold)
                    if not os.path.isdir(cls_dir):
                        continue
                    for fn in os.listdir(cls_dir):
                        if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                            p = os.path.join(cls_dir, fn)
                            self.paths.append(p)
                            # label index is index in ckpt_classes
                            self.labels.append(self.ckpt_classes.index(cls_name))
            if skipped:
                print(f"Skipped {len(skipped)} classes not found in splits directory: {skipped[:10]}")

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        p = self.paths[idx]
        img = Image.open(p).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx], p

class NonFoodDataset(Dataset):
    """Collect images from root_dir/(train|val|test) combining all folds."""
    def __init__(self, root_dir, folds=None, transform=None, ckpt_classes=None):
        self.paths = []
        if folds is None:
            folds = ['train', 'val', 'test']
        for fold in folds:
            fold_dir = os.path.join(root_dir, fold)
            if not os.path.isdir(fold_dir):
                continue
            for fn in os.listdir(fold_dir):
                if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                    self.paths.append(os.path.join(fold_dir, fn))
        self.transform = transform
        # if ckpt is binary, record indices for mapping when saving/analysis
        self.ckpt_classes = list(ckpt_classes) if ckpt_classes is not None else None

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        p = self.paths[idx]
        img = Image.open(p).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, p

# %%
# Section 8 — Build datasets and dataloaders
BATCH_SIZE = 32
NUM_WORKERS = 0

# Combine train/val/test for food dataset using folds
FOLDS = ['train', 'val', 'test']
food_dataset = ImageFolderFlat(SPLITS_DIR, classes, folds=FOLDS, transform=eval_tfms)
food_loader = DataLoader(food_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
print('Food dataset size (combined folds):', len(food_dataset))

# Non-food dataset: combine all folds under NON_FOOD_DIR
nonfood_dataset = NonFoodDataset(NON_FOOD_DIR, folds=FOLDS, transform=eval_tfms)
nonfood_loader = DataLoader(nonfood_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
print('Non-food dataset size (combined folds):', len(nonfood_dataset))
# Out:
# Binary checkpoint detected. Collected 43400 images from splits and labeled them as 'food' (idx=0).
# Food dataset size (combined folds): 43400
# Non-food dataset size (combined folds): 5012

# %%
# Section 9 — Inference helper
import math

# Determine if checkpoint is binary and get food index
binary_mode, food_idx, not_food_idx = _detect_binary_food_ckpt(classes)
if binary_mode:
    print(f"Binary model detected. food_idx={food_idx}, not_food_idx={not_food_idx}")

def run_inference(model, loader, device, topk=5):
    """Run inference.

    For binary models (food vs not_food) returns per-image dict with 'path', 'gt_idx', 'food_prob' and 'pred_label'.
    For multi-class models returns 'topk' as before.
    """
    results = []
    model.to(device)
    model.eval()
    with torch.no_grad():
        for batch in loader:
            # batch may be (imgs, labels, paths) or (imgs, paths)
            if len(batch) == 3:
                imgs, labels, paths = batch
            else:
                imgs, paths = batch
                labels = [None] * len(paths)
            imgs = imgs.to(device)
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            for i in range(probs.shape[0]):
                row = probs[i]
                if binary_mode:
                    # use food index probability
                    food_probability = float(row[food_idx])
                    pred_label = classes[int(row.argmax())]
                    results.append({
                        'path': paths[i],
                        'gt_idx': int(labels[i]) if labels is not None and labels[i] is not None else None,
                        'food_prob': food_probability,
                        'pred_label': pred_label,
                    })
                else:
                    top_idx = row.argsort()[-topk:][::-1]
                    top_probs = row[top_idx]
                    top_classes = [classes[j] for j in top_idx]
                    results.append({
                        'path': paths[i],
                        'gt_idx': int(labels[i]) if labels is not None and labels[i] is not None else None,
                        'topk': list(zip(top_classes, [float(x) for x in top_probs]))
                    })
    return results
# Out:
# Binary model detected. food_idx=0, not_food_idx=1

# %%
# Section 10 — Run inference on food dataset and compute metrics
CONF_THRESH = 0.7

food_results = run_inference(model, food_loader, device, topk=5)

if binary_mode:
    # For binary model we expect all food_dataset samples to be positive (we labeled them as food_idx)
    total_food = len(food_results)
    detected_food = 0
    missed_food = []
    food_probs = []
    for r in food_results:
        prob = r.get('food_prob', 0.0)
        food_probs.append(prob)
        if prob >= CONF_THRESH:
            detected_food += 1
        else:
            missed_food.append(r['path'])
    tpr = detected_food / total_food if total_food else 0.0
    print(f'Food detection on combined folds: {total_food} images. Detected (>= {CONF_THRESH}): {detected_food}. TPR: {tpr:.4f}')
    print(f'Collected {len(missed_food)} missed food images (prob < {CONF_THRESH})')
    # Prepare bad_images_by_class-like structure for compatibility (single key 'food')
    bad_images_by_class = {'food': missed_food}
    # Optionally save distribution stats
    import statistics
    print('Food prob mean:', statistics.mean(food_probs) if food_probs else 0.0)
    print('Food prob median:', statistics.median(food_probs) if food_probs else 0.0)
else:
    # Multiclass path (unchanged)
    correct1 = 0
    correct5 = 0
    bad_images_by_class = {}
    for r in food_results:
        gt = r['gt_idx']
        topk = r['topk']  # list of (class_name, prob)
        top_classes = [t[0] for t in topk]
        top_probs = [t[1] for t in topk]
        # top1
        if gt is not None and classes[gt] == top_classes[0]:
            correct1 += 1
        # top5
        if gt is not None and classes[gt] in top_classes:
            correct5 += 1
            idx = top_classes.index(classes[gt])
            if top_probs[idx] < CONF_THRESH:
                bad_images_by_class.setdefault(classes[gt], []).append(r['path'])
        else:
            # GT not in top5
            bad_images_by_class.setdefault(classes[gt] if gt is not None else 'UNKNOWN', []).append(r['path'])

    n = len(food_results)
    acc1 = correct1 / n if n else 0.0
    acc5 = correct5 / n if n else 0.0
    print(f'Food dataset: {n} images. Top-1 acc: {acc1:.4f}, Top-5 acc: {acc5:.4f}')
    print('Bad images (per-class counts):')
    for k,v in bad_images_by_class.items():
        print(k, len(v))
# Out:
# Food detection on combined folds: 43400 images. Detected (>= 0.7): 42414. TPR: 0.9773
# Collected 986 missed food images (prob < 0.7)
# Food prob mean: 0.9788837714462992
# Food prob median: 0.9999914169311523

# %%
# Section 11 — Run inference on non-food and flag confident predictions
import shutil

non_food_flagged = []
model.to(device)
model.eval()
with torch.no_grad():
    for imgs, paths in nonfood_loader:
        imgs = imgs.to(device)
        logits = model(imgs)
        probs = torch.softmax(logits, dim=1).cpu().numpy()
        for i in range(probs.shape[0]):
            row = probs[i]
            if binary_mode:
                food_probability = float(row[food_idx])
                pred_label = classes[int(row.argmax())]
                # All images in this dataset are expected to be NOT food (ground-truth = not_food_idx)
                gt_idx = not_food_idx
                if food_probability >= CONF_THRESH:
                    # false positive: non-food image predicted as food with high confidence
                    non_food_flagged.append({
                        'path': paths[i],
                        'food_prob': food_probability,
                        'pred_label': pred_label,
                        'gt_idx': gt_idx,
                    })
            else:
                max_idx = int(row.argmax())
                max_prob = float(row[max_idx])
                if max_prob >= CONF_THRESH:
                    non_food_flagged.append({
                        'path': paths[i],
                        'pred_class': classes[max_idx],
                        'prob': max_prob,
                        'gt_idx': None,
                    })

# Compute non-food metrics: total, false positives, true negatives, FPR, specificity
total_nonfood = len(nonfood_dataset)
false_positives = len(non_food_flagged)
true_negatives = total_nonfood - false_positives
fpr = false_positives / total_nonfood if total_nonfood else 0.0
specificity = true_negatives / total_nonfood if total_nonfood else 0.0
print('Non-food images total:', total_nonfood)
print('Non-food images flagged (confident predictions / false positives):', false_positives)
print(f'False positive rate (FPR): {fpr:.4f}  | Specificity (TN / N): {specificity:.4f}')
# Out:
# Non-food images total: 5012
# Non-food images flagged (confident predictions / false positives): 7
# False positive rate (FPR): 0.0014  | Specificity (TN / N): 0.9986

# %%
# Section 12 — Save results and optionally copy flagged images
bad_json = os.path.join(OUTPUT_DIR, 'bad_images_by_class.json')
nonfood_json = os.path.join(OUTPUT_DIR, 'non_food_confident.json')

with open(bad_json, 'w') as f:
    json.dump(bad_images_by_class, f, indent=2)
with open(nonfood_json, 'w') as f:
    json.dump(non_food_flagged, f, indent=2)

print('Saved:', bad_json)
print('Saved:', nonfood_json)

COPY_FLAGGED = True
if COPY_FLAGGED:
    bad_out_dir = os.path.join(OUTPUT_DIR, 'bad_images_by_class')
    nonfood_out_dir = os.path.join(OUTPUT_DIR, 'non_food_confident')
    os.makedirs(bad_out_dir, exist_ok=True)
    os.makedirs(nonfood_out_dir, exist_ok=True)
    # copy non-food
    for item in non_food_flagged:
        dst = os.path.join(nonfood_out_dir, os.path.basename(item['path']))
        try:
            shutil.copy(item['path'], dst)
        except Exception as e:
            print('Copy error:', e)
    # copy bad images by class
    for cls_name, paths in bad_images_by_class.items():
        cls_dir = os.path.join(bad_out_dir, cls_name)
        os.makedirs(cls_dir, exist_ok=True)
        for p in paths:
            try:
                shutil.copy(p, os.path.join(cls_dir, os.path.basename(p)))
            except Exception as e:
                print('Copy error:', e)
    print('Flagged images copied to:', bad_out_dir, 'and', nonfood_out_dir)
# Out:
# Saved: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class.json
# Saved: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.json
# Flagged images copied to: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class and d:\VSC FILES\testtrain\inference_outputs\non_food_confident

# %%
# Section 13 — Summary & quick checks
print('\nSummary:')
print('Food images total:', len(food_dataset))
print('Non-food images total:', len(nonfood_dataset))

# Print appropriate metrics depending on model type
if binary_mode:
    if 'tpr' in globals():
        print(f'Detected (TPR) at threshold {CONF_THRESH}:', f"{detected_food}/{total_food} = {tpr:.4f}")
    else:
        print('Run Section 10 to compute detection metrics (TPR).')
    # Non-food metrics (if computed)
    if 'total_nonfood' in globals():
        print(f'Non-food: Total={total_nonfood}, False positives={false_positives}, FPR={fpr:.4f}, Specificity={specificity:.4f}')
    else:
        print('Run Section 11/11.5 to compute non-food false positive metrics.')
else:
    # multiclass metrics
    if 'acc1' in globals() and 'acc5' in globals():
        print('Top-1 acc:', acc1)
        print('Top-5 acc:', acc5)
    else:
        print('Run Section 10 to compute multiclass accuracy metrics.')

print('Bad images saved to:', bad_json)
print('Non-food flagged saved to:', nonfood_json)

# Quick sanity checks
if not os.path.exists(bad_json):
    print('Warning: bad_images JSON missing')
if not os.path.exists(nonfood_json):
    print('Warning: non-food JSON missing')

print('\nDone.')
# Out:
# Summary:
# Food images total: 43400
# Non-food images total: 5012
# Detected (TPR) at threshold 0.7: 42414/43400 = 0.9773
# Non-food: Total=5012, False positives=7, FPR=0.0014, Specificity=0.9986
# Bad images saved to: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class.json
# Non-food flagged saved to: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.json
#
# Done.

# %%
# Section 12.5 — List images below confidence threshold
# Shows all food images (from splits) where food probability < CONF_THRESH
print(f"Listing images with food probability < {CONF_THRESH}:\n")
if binary_mode:
    low_conf = bad_images_by_class.get('food', [])
    print(f'Found {len(low_conf)} food images below {CONF_THRESH}\n')
    # print full paths; if many, show first 200 to avoid flooding
    max_show = 10000
    for i, p in enumerate(low_conf):
        if i >= max_show:
            print(f"... ({len(low_conf)-max_show} more) ...")
            break
        print(p)
else:
    # For multiclass models, bad_images_by_class already collects low-confidence/misranked images
    total = 0
    for cls, paths in bad_images_by_class.items():
        print(f"Class: {cls} -> {len(paths)} images")
        total += len(paths)
        for p in paths[:200]:
            print(p)
    print(f"Total low-confidence images across classes: {total}")
# Out:
# Listing images with food probability < 0.7:
#
# Found 986 food images below 0.7
#
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_45.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\test\adobong_pusit_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_108.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_132.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_134.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_139.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_141.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_196.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_229.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_275.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_279.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_291.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_343.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_347.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_41.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_47.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_55.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_67.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_74.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\apple_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\apple_297.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\apple_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\apple_91.jpg
# D:\VSC FILES\testtrain\splits_new_v2\arroz_caldo\val\arroz_caldo_324.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baby_back_ribs\train\baby_back_ribs_105.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baby_back_ribs\train\baby_back_ribs_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baby_back_ribs\train\baby_back_ribs_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baby_back_ribs\train\baby_back_ribs_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_295.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_337.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_360.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_363.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_631.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\val\baked_tahong_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\val\baked_tahong_581.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\test\baked_tahong_472.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\test\baked_tahong_518.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_366.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_394.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_455.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_52.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_550.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_647.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_654.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_81.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\intro-1705686781.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\Screenshot 2025-08-17 100901.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_353.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\Screenshot 2025-08-17 153259.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\test\balut_115.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_136.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_144.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_192.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_221.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_340.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\test\beef_bistek_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_kaldereta\train\beef_kaldereta_23.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_kaldereta\train\beef_kaldereta_250.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_18.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\val\beef_tartare_145.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\test\beef_tartare_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_167.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_235.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_340.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_187.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_28.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\test\beignets_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\test\beignets_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_335.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_84.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_114.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_164.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_168.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_193.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_212.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_22.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_23.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_237.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_25.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_298.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_302.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_310.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_330.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_61.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\val\biko_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\val\biko_50.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\test\biko_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\test\biko_92.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_139.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_157.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_257.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_273.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_275.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_54.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\val\boiled_egg_149.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\val\boiled_egg_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\val\boiled_egg_5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\test\boiled_egg_315.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bread_pudding\train\bread_pudding_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bread_pudding\train\bread_pudding_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\train\caesar_salad_296.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\train\caesar_salad_74.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\test\caesar_salad_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_200.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_229.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_275.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\val\cannoli_308.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\test\cannoli_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\test\cannoli_341.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_164.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_217.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_235.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_245.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_258.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_326.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_73.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\val\cheesecake_140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_adobo\train\chicken_adobo_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_adobo\train\chicken_adobo_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\train\chicken_curry_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\val\chicken_curry_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\test\chicken_curry_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_quesadilla\test\chicken_quesadilla_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_316.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_79.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_120.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_141.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_168.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_173.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_180.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_195.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_229.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_250.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_278.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_300.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_309.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_323.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_334.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_81.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_82.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\val\chocolate_cake_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\val\chocolate_cake_29.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_123.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_132.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_176.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_193.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_224.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_225.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_243.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_247.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_282.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_287.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_30.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_32.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_338.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_72.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_188.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\test\chocolate_mousse_266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_129.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_180.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_30.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_305.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_326.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_328.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_336.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_338.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_350.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_352.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_79.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\test\churros_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\test\churros_144.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\test\churros_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\test\churros_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\test\churros_90.jpg
# D:\VSC FILES\testtrain\splits_new_v2\club_sandwich\train\club_sandwich_14.jpg
# D:\VSC FILES\testtrain\splits_new_v2\club_sandwich\train\club_sandwich_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\club_sandwich\val\club_sandwich_89.jpg
# D:\VSC FILES\testtrain\splits_new_v2\creme_brulee\train\creme_brulee_16.jpg
# D:\VSC FILES\testtrain\splits_new_v2\creme_brulee\train\creme_brulee_210.jpg
# D:\VSC FILES\testtrain\splits_new_v2\creme_brulee\val\creme_brulee_143.jpg
# D:\VSC FILES\testtrain\splits_new_v2\creme_brulee\val\creme_brulee_228.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_168.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_192.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_247.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_45.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_60.jpg
# D:\VSC FILES\testtrain\splits_new_v2\crispy_pata\train\crispy_pata_85.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_108.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_11.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_141.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_154.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_156.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_162.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_165.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_210.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_223.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_232.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_253.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_260.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_291.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_292.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_295.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_302.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_33.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_335.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_338.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_41.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_52.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_61.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_77.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_87.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_92.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\train\cup_cakes_93.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_20.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_228.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_297.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_308.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_324.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\val\cup_cakes_5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\test\cup_cakes_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\test\cup_cakes_267.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\test\cup_cakes_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cup_cakes\test\cup_cakes_90.jpg
# D:\VSC FILES\testtrain\splits_new_v2\daing_na_bangus\train\daing_na_bangus_134.jpg
# D:\VSC FILES\testtrain\splits_new_v2\daing_na_bangus\train\daing_na_bangus_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\daing_na_bangus\train\daing_na_bangus_320.jpg
# D:\VSC FILES\testtrain\splits_new_v2\daing_na_bangus\train\daing_na_bangus_34.jpg
# D:\VSC FILES\testtrain\splits_new_v2\daing_na_bangus\train\daing_na_bangus_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dinakdakan\train\dinakdakan_244.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dinakdakan\train\dinakdakan_290.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_113.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_131.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_157.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_166.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_222.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_272.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_305.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_336.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_69.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_79.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\train\donuts_88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\val\donuts_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\val\donuts_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\val\donuts_28.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\test\donuts_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\test\donuts_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\test\donuts_237.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\test\donuts_248.jpg
# D:\VSC FILES\testtrain\splits_new_v2\donuts\test\donuts_306.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_113.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_127.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_172.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_182.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_193.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_281.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_284.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_303.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_334.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\train\dumplings_82.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\val\dumplings_5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\dumplings\test\dumplings_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\eggs_benedict\val\eggs_benedict_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\falafel\train\falafel_109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\falafel\train\falafel_173.jpg
# D:\VSC FILES\testtrain\splits_new_v2\falafel\train\falafel_212.jpg
# D:\VSC FILES\testtrain\splits_new_v2\falafel\test\falafel_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\falafel\test\falafel_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_172.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_215.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_227.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\train\fish_balls_343.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_balls\val\fish_balls_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fish_sinigang\train\fish_sinigang_183.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_14.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_225.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_256.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\train\french_fries_84.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\val\french_fries_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_fries\test\french_fries_306.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_toast\train\french_toast_131.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_toast\train\french_toast_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\french_toast\train\french_toast_304.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_calamari\train\fried_calamari_270.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_chicken\train\fried_chicken_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_chicken\train\fried_chicken_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_chicken\test\fried_chicken_362.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_189.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_207.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_217.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_32.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\fried_rice\train\fried_rice_87.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_11.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_111.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_132.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_166.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_207.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_223.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_246.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_347.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\train\frozen_yogurt_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\val\frozen_yogurt_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\val\frozen_yogurt_241.jpg
# D:\VSC FILES\testtrain\splits_new_v2\frozen_yogurt\test\frozen_yogurt_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\garlic_bread\train\garlic_bread_286.jpg
# D:\VSC FILES\testtrain\splits_new_v2\garlic_bread\train\garlic_bread_336.jpg
# D:\VSC FILES\testtrain\splits_new_v2\garlic_buttered_shrimp\train\garlic_buttered_shrimp_270.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ginisang_munggo\val\ginisang_munggo_154.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_cheese_sandwich\train\grilled_cheese_sandwich_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_cheese_sandwich\train\grilled_cheese_sandwich_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_cheese_sandwich\train\grilled_cheese_sandwich_217.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_cheese_sandwich\test\grilled_cheese_sandwich_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_salmon\train\grilled_salmon_127.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_salmon\train\grilled_salmon_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_salmon\val\grilled_salmon_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\grilled_salmon\test\grilled_salmon_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_134.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_276.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_294.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\train\guacamole_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\val\guacamole_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\guacamole\val\guacamole_28.jpg
# D:\VSC FILES\testtrain\splits_new_v2\gyoza\train\gyoza_146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\gyoza\train\gyoza_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\gyoza\val\gyoza_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\gyoza\test\gyoza_91.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_111.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_114.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_183.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_187.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_196.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_20.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_22.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_302.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_360.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_441.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_48.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_54.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_69.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\train\halo_halo_79.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\val\halo_halo_230.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\test\halo_halo_146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\halo_halo\test\halo_halo_23.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hamburger\train\hamburger_10.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hamburger\train\hamburger_64.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hamburger\train\hamburger_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hamburger\test\hamburger_248.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_189.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_200.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_273.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_279.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_296.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_39.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\train\hot_dog_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\val\hot_dog_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\val\hot_dog_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\val\hot_dog_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\test\hot_dog_234.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hot_dog\test\hot_dog_267.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hotsilog\train\hotsilog_15.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\train\hummus_183.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\train\hummus_191.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\train\hummus_225.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\train\hummus_286.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\train\hummus_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\val\hummus_259.jpg
# D:\VSC FILES\testtrain\splits_new_v2\hummus\test\hummus_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_105.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_108.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_171.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_176.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_193.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_204.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_212.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_216.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_222.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_249.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_261.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_287.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_292.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_295.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_305.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_48.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_81.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\train\ice_cream_93.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\val\ice_cream_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\val\ice_cream_20.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\val\ice_cream_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\val\ice_cream_228.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\val\ice_cream_89.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\test\ice_cream_264.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\test\ice_cream_267.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\test\ice_cream_288.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ice_cream\test\ice_cream_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_223.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_224.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_255.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_257.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_263.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_313.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_371.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_375.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\train\isaw_manok_69.jpg
# D:\VSC FILES\testtrain\splits_new_v2\isaw_manok\test\isaw_manok_206.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kikiam\train\kikiam_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kikiam\train\kikiam_92.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kwek_kwek\train\kwek_kwek_204.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kwek_kwek\train\kwek_kwek_298.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kwek_kwek\train\kwek_kwek_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\kwek_kwek\val\kwek_kwek_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lasagna\train\lasagna_136.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lasagna\train\lasagna_216.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lasagna\train\lasagna_36.jpg
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\train\leche_flan_163.jpg
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\train\leche_flan_50.jpg
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\train\Screenshot 2025-08-23 171934.png
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\train\Screenshot 2025-08-23 172022.png
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\train\Screenshot 2025-08-23 173512.png
# D:\VSC FILES\testtrain\splits_new_v2\leche_flan\test\leche_flan_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_105.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_221.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_361.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\train\lechon_baboy_88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\test\lechon_baboy_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_baboy\test\lechon_baboy_294.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_manok\train\lechon_manok_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_manok\train\lechon_manok_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_manok\train\lechon_manok_255.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_manok\train\lechon_manok_309.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lechon_manok\train\lechon_manok_342.jpg
# D:\VSC FILES\testtrain\splits_new_v2\longganisa\train\longganisa_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lumpiang_shanghai\train\lumpiang_shanghai_110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lumpiang_shanghai\train\lumpiang_shanghai_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lumpiang_shanghai\train\lumpiang_shanghai_60.jpg
# D:\VSC FILES\testtrain\splits_new_v2\lumpiang_shanghai\train\lumpiang_shanghai_7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_122.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_204.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_207.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_208.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_209.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_213.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_229.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_258.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_272.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_289.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_293.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_310.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_312.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_313.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_335.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_342.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_52.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_69.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_74.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\train\macarons_77.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_106.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_143.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_152.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_187.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_29.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\val\macarons_75.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\test\macarons_101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\test\macarons_177.jpg
# D:\VSC FILES\testtrain\splits_new_v2\macarons\test\macarons_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_203.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_246.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_254.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_270.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_80.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\train\mussels_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\val\mussels_130.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\val\mussels_145.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\val\mussels_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\mussels\test\mussels_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\nachos\train\nachos_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\nachos\train\nachos_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\nachos\train\nachos_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\nachos\train\nachos_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\omelette\test\omelette_137.jpg
# D:\VSC FILES\testtrain\splits_new_v2\onion_rings\train\onion_rings_134.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_191.jpg
# D:\VSC FILES\testtrain\splits_new_v2\orange\train\orange_205.jpg
# ...
# D:\VSC FILES\testtrain\splits_new_v2\pork_sisig\val\pork_sisig_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pork_sisig\val\pork_sisig_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pork_sisig\test\pork_sisig_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\prime_rib\train\prime_rib_236.jpg
# D:\VSC FILES\testtrain\splits_new_v2\prime_rib\train\prime_rib_281.jpg
# D:\VSC FILES\testtrain\splits_new_v2\prime_rib\train\prime_rib_344.jpg
# D:\VSC FILES\testtrain\splits_new_v2\prime_rib\test\prime_rib_280.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_128.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_347.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_36.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_368.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_69.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\train\pritong_galunggong_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\val\pritong_galunggong_264.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\val\pritong_galunggong_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_galunggong\test\pritong_galunggong_30.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_188.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_259.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_264.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_283.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\train\pritong_tilapia_84.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\val\pritong_tilapia_295.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\test\pritong_tilapia_48.jpg
# D:\VSC FILES\testtrain\splits_new_v2\pritong_tilapia\test\pritong_tilapia_54.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_162.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_176.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_303.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_98.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\val\puto_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_15.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_165.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\test\ramen_341.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_199.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_200.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_223.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_257.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_45.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\val\red_velvet_cake_308.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\test\red_velvet_cake_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_115.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_176.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_19.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_210.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_212.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_227.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_249.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_292.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_305.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_336.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_34.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_350.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_48.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\val\sashimi_188.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\val\sashimi_20.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_234.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_91.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_32.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_333.jpg
# D:\VSC FILES\testtrain\splits_new_v2\scallops\val\scallops_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\shrimp_sinigang\val\shrimp_sinigang_15.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_174.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\test\sipo_egg_270.jpg
# D:\VSC FILES\testtrain\splits_new_v2\spaghetti_bolognese\test\spaghetti_bolognese_90.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\train\steak_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\val\steak_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\test\steak_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\test\steak_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_158.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_278.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_289.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_300.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_350.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\val\strawberry_3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\test\strawberry_51.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_163.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sunny_side_up\train\sunny_side_up_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_122.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_19.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_191.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_273.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_327.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_346.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_54.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_78.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\val\sushi_152.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\val\sushi_332.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\val\sushi_5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_49.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_286.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_47.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\val\tacos_241.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\test\tacos_177.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_328.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_337.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_342.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_353.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\val\taho_331.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_247.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_281.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_282.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_293.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_39.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\val\takoyaki_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\test\takoyaki_315.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_213.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_267.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_268.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_77.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\val\tuyo_187.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\val\tuyo_188.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\val\tuyo_297.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\val\tuyo_332.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\test\tuyo_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_261.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_291.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_39.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\val\waffles_152.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\val\waffles_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\val\waffles_190.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\test\waffles_319.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\test\waffles_49.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_129.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_131.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_157.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_162.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_166.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_204.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_227.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_55.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_97.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_98.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\val\white_rice_152.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_339.jpg

# %%
# Section 11.5 — Ensure non-food inference ran and list flagged non-food images
import csv

# If non_food_flagged isn't defined, run the non-food inference loop now
if 'non_food_flagged' not in globals():
    non_food_flagged = []
    model.to(device)
    model.eval()
    with torch.no_grad():
        for imgs, paths in nonfood_loader:
            imgs = imgs.to(device)
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            for i in range(probs.shape[0]):
                row = probs[i]
                if binary_mode:
                    food_probability = float(row[food_idx])
                    pred_label = classes[int(row.argmax())]
                    gt_idx = not_food_idx
                    if food_probability >= CONF_THRESH:
                        non_food_flagged.append({
                            'path': paths[i],
                            'food_prob': food_probability,
                            'pred_label': pred_label,
                            'gt_idx': gt_idx,
                        })
                else:
                    max_idx = int(row.argmax())
                    max_prob = float(row[max_idx])
                    if max_prob >= CONF_THRESH:
                        non_food_flagged.append({
                            'path': paths[i],
                            'pred_class': classes[max_idx],
                            'prob': max_prob,
                            'gt_idx': None,
                        })

# Recompute non-food summary metrics if they don't exist
total_nonfood = len(nonfood_dataset)
false_positives = len(non_food_flagged)
true_negatives = total_nonfood - false_positives
fpr = false_positives / total_nonfood if total_nonfood else 0.0
specificity = true_negatives / total_nonfood if total_nonfood else 0.0
print('Non-food images flagged (confident predictions):', false_positives)

# Save CSV with results for easier review
csv_path = os.path.join(OUTPUT_DIR, 'non_food_confident.csv')
with open(csv_path, 'w', newline='', encoding='utf-8') as cf:
    if binary_mode:
        fieldnames = ['path','food_prob','pred_label','gt_idx']
    else:
        fieldnames = ['path','pred_class','prob','gt_idx']
    writer = csv.DictWriter(cf, fieldnames=fieldnames)
    writer.writeheader()
    for item in non_food_flagged:
        writer.writerow(item)
print('Saved non-food flagged CSV to:', csv_path)

# Print first 200 flagged examples (or fewer) for quick inspection
for i, item in enumerate(non_food_flagged[:200]):
    if binary_mode:
        print(i+1, item['path'], f"food_prob={item['food_prob']:.3f}", 'pred=', item.get('pred_label'), 'gt_idx=', item.get('gt_idx'))
    else:
        print(i+1, item['path'], item.get('prob'), item.get('pred_class'))

print(f'Non-food summary -> Total: {total_nonfood}, False positives: {false_positives}, FPR: {fpr:.4f}, Specificity: {specificity:.4f}')

# Optionally copy these flagged non-food images to output folder (already done in Section 12 if COPY_FLAGGED)
if not COPY_FLAGGED:
    print('\nTo copy flagged images to disk, set COPY_FLAGGED = True and re-run Section 12.')
# Out:
# Non-food images flagged (confident predictions): 7
# Saved non-food flagged CSV to: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.csv
# 1 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000313_IMG_20220603_175735.jpg food_prob=1.000 pred= food gt_idx= 1
# 2 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\001328_fefea57d65ac52136f2e55a13e1ad17f.jpg food_prob=1.000 pred= food gt_idx= 1
# 3 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\002355_non_food_000378.jpg food_prob=0.874 pred= food gt_idx= 1
# 4 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003530_514267266_25378001535137666_1063305567482256627_n.jpg food_prob=1.000 pred= food gt_idx= 1
# 5 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003768_non_food_001331.jpg food_prob=0.999 pred= food gt_idx= 1
# 6 D:\VSC FILES\testtrain\food_not_food_ds\not_food\val\000498_c561c2a77d5b9b03702efc423b18cb9a.jpg food_prob=0.818 pred= food gt_idx= 1
# 7 D:\VSC FILES\testtrain\food_not_food_ds\not_food\test\000017_123_da47b22102623a9f809aa3a98987717c.jpg.jpg food_prob=1.000 pred= food gt_idx= 1
# Non-food summary -> Total: 5012, False positives: 7, FPR: 0.0014, Specificity: 0.9986
