# %% [markdown]
# # Test model: food classes (splits_new_v2) and non-food (food_not_food_ds)
#
# This notebook loads the fine-tuned EfficientNet-B3 checkpoint and runs inference on:
#
# - All food classes from `d:\\VSC FILES\\testtrain\\splits_new_v2` (test folders)
# - Non-food test images from `d:\\VSC FILES\\testtrain\\food_not_food_ds\\not_food\\test`
#
# Edit variables in the first code cell (ckpt_path, dataset roots, batch_size, threshold) before running.

# %%
# Section 1 — Environment & Dependencies

# (Optional) create a minimal requirements file. Edit as needed.
requirements = '''torch torchvision pillow torch-directml numpy'''
with open('requirements.txt', 'w') as f:
    f.write(requirements)

# Example: install packages (uncomment to run). On Windows with bash shell you can run these cells.
# %%bash
# pip install -r requirements.txt

print('requirements.txt written. Review and install packages if needed.')
# Out:
# requirements.txt written. Review and install packages if needed.

# %%
# Section 2 — Project structure (show top-level files/folders)
import os
root = r'd:\VSC FILES\testtrain'
print('Workspace root:', root)
for entry in sorted(os.listdir(root))[:80]:
    print(entry)

print('\nNotebook file: d:\\VSC FILES\\testtrain\\test_inference_nonfood_and_food.ipynb')
# Out:
# Workspace root: d:\VSC FILES\testtrain
# HF_ready.ipynb
# bad_images_by_class.json
# class_names.json
# export_to_onxx.ipynb
# fine_tune.ipynb
# fine_tune2.ipynb
# fine_tune2_.ipynb
# fine_tune2__.ipynb
# food-101-split
# food_not_food_ds
# hf_package
# model.onnx
# new_model.onnx
# new_splits
# new_train.ipynb
# nutrisight_model_training
# onxx
# openimages_downloads
# requirements.txt
# runs
# runs copy
# splits_new
# splits_new_v2
# test.ipynb
# test_inference_nonfood_and_food.ipynb
# test_model.ipynb
# test_model_finetune.ipynb
# test_model_finetune2.ipynb
# test_model_on_all_food_dataset_images.ipynb
# thesis-model-resnet50-20250824-230424
# thesis_datasets
# thesis_datasets_cleaned
# thesis_datasets_cleaned_split
# thesis_datasets_split
# train.ipynb
# train_efficientnet_b3_optimized.ipynb
# train_efficientnet_b3_optimized_food_not_food.ipynb
# train_efficientnet_b3_optimized_food_not_foodv2.ipynb
#
# Notebook file: d:\VSC FILES\testtrain\test_inference_nonfood_and_food.ipynb

# %%
# Section 3 — Import libraries
import os
import json
import torch
import torch.nn as nn
from torchvision import transforms, models
from PIL import Image
import numpy as np
from torch.utils.data import Dataset, DataLoader

# Optional import for DirectML
try:
    import torch_directml
    has_directml = True
except Exception:
    has_directml = False

print('torch:', torch.__version__)
print('torch_directml available:', has_directml)
# Out:
# torch: 2.4.1+cpu
# torch_directml available: True

# %%
# Section 4 — Device selection
try:
    if has_directml:
        dml = torch_directml.device()
        device = dml
    else:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
except Exception as e:
    print('Device selection error, falling back to CPU:', e)
    device = torch.device('cpu')

print('Using device:', device)
# Out:
# Using device: privateuseone:0

# %%
# Section 5 — Paths and checkpoint
# Edit these paths if needed
CKPT_PATH = r'D:\VSC FILES\testtrain\runs\efficientnet_b3_food_not_food-20251115-190720\best_efficientnet_b3.pth'
SPLITS_DIR = r'D:\VSC FILES\testtrain\splits_new_v2'
# Use the non-food root (contains train/val/test). We'll combine all folds.
NON_FOOD_DIR = r'D:\VSC FILES\testtrain\food_not_food_ds\not_food'
OUTPUT_DIR = r'd:\VSC FILES\testtrain\inference_outputs'
os.makedirs(OUTPUT_DIR, exist_ok=True)

print('Checkpoint exists?', os.path.exists(CKPT_PATH))

ckpt = torch.load(CKPT_PATH, map_location='cpu')
# Expected keys: 'classes', 'model_state', optionally 'mean','std','image_size'
classes = ckpt.get('classes') or ckpt.get('class_names')
if classes is None:
    raise RuntimeError('Checkpoint does not contain class list under "classes" or "class_names"')

mean = ckpt.get('mean', [0.485, 0.456, 0.406])
std = ckpt.get('std', [0.229, 0.224, 0.225])
image_size = ckpt.get('image_size', 300)  # default used during training
print('Loaded checkpoint. Model classes:', len(classes))
# Out:
# Checkpoint exists? True
# Loaded checkpoint. Model classes:
# C:\Users\JP\AppData\Local\Temp\ipykernel_20144\147732427.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(CKPT_PATH, map_location='cpu')
#  2

# %%
# Section 6 — Build model
num_classes = len(classes)
model = models.efficientnet_b3(weights=None)
# Replace classifier to match training code pattern
if hasattr(model, 'classifier'):
    # EfficientNet classifier is usually model.classifier[1]
    try:
        in_feats = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(in_feats, num_classes)
    except Exception:
        # fallback
        model.classifier = nn.Linear(model.classifier.in_features, num_classes)
else:
    # Generic fallback - replace last linear if found
    for name, module in reversed(list(model.named_modules())):
        if isinstance(module, nn.Linear):
            parent = model
            break

# Load weights (support different key names)
state_key = 'model_state' if 'model_state' in ckpt else 'state_dict' if 'state_dict' in ckpt else None
if state_key is None:
    raise RuntimeError('Checkpoint missing model_state/state_dict')
model.load_state_dict(ckpt[state_key])
model = model.to(device)
model.eval()
print('Model loaded and set to eval() on device', device)
# Out:
# Model loaded and set to eval() on device privateuseone:0

# %%
# Section 7 — Transforms and Datasets
from torchvision import transforms

eval_tfms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std),
])

# Helper to detect binary food/not_food checkpoint
def _detect_binary_food_ckpt(ckpt_classes):
    lower = [c.lower().replace(' ', '_').replace('-', '_') for c in ckpt_classes]
    food_idx = None
    not_food_idx = None
    for i, c in enumerate(lower):
        if c == 'food':
            food_idx = i
        if c in ('not_food', 'notfood', 'not_foods', 'not_food', 'nonfood', 'non_food', 'not food'):
            not_food_idx = i
    # also allow when only 'food' and 'not_food' are present in some variant
    if food_idx is not None and not_food_idx is not None:
        return True, food_idx, not_food_idx
    return False, food_idx, not_food_idx

class ImageFolderFlat(Dataset):
    """Collect images from <splits_root>/<class>/(train|val|test) and map labels to indices in ckpt['classes'] so indices align with model outputs.

    If the checkpoint is a binary food/not_food model, this class will treat all images under every class in `splits_root` as `food` (label index = index of 'food' in checkpoint)."""
    def __init__(self, splits_root, ckpt_classes, folds=None, transform=None):
        self.paths = []
        self.labels = []
        self.transform = transform
        self.ckpt_classes = list(ckpt_classes)
        # default folds to combine
        if folds is None:
            folds = ['train', 'val', 'test']
        # detect binary ckpt
        binary_mode, food_idx, not_food_idx = _detect_binary_food_ckpt(self.ckpt_classes)
        available = [d for d in os.listdir(splits_root) if os.path.isdir(os.path.join(splits_root, d))]
        available = set(available)
        skipped = []
        if binary_mode:
            # collect ALL images under every class folder and label them as 'food'
            for cls_dir_name in sorted(available):
                for fold in folds:
                    cls_dir = os.path.join(splits_root, cls_dir_name, fold)
                    if not os.path.isdir(cls_dir):
                        continue
                    for fn in os.listdir(cls_dir):
                        if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                            p = os.path.join(cls_dir, fn)
                            self.paths.append(p)
                            self.labels.append(food_idx)
            print(f"Binary checkpoint detected. Collected {len(self.paths)} images from splits and labeled them as 'food' (idx={food_idx}).")
        else:
            for cls_name in self.ckpt_classes:
                if cls_name not in available:
                    skipped.append(cls_name)
                    continue
                for fold in folds:
                    cls_dir = os.path.join(splits_root, cls_name, fold)
                    if not os.path.isdir(cls_dir):
                        continue
                    for fn in os.listdir(cls_dir):
                        if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                            p = os.path.join(cls_dir, fn)
                            self.paths.append(p)
                            # label index is index in ckpt_classes
                            self.labels.append(self.ckpt_classes.index(cls_name))
            if skipped:
                print(f"Skipped {len(skipped)} classes not found in splits directory: {skipped[:10]}")

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        p = self.paths[idx]
        img = Image.open(p).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx], p

class NonFoodDataset(Dataset):
    """Collect images from root_dir/(train|val|test) combining all folds."""
    def __init__(self, root_dir, folds=None, transform=None, ckpt_classes=None):
        self.paths = []
        if folds is None:
            folds = ['train', 'val', 'test']
        for fold in folds:
            fold_dir = os.path.join(root_dir, fold)
            if not os.path.isdir(fold_dir):
                continue
            for fn in os.listdir(fold_dir):
                if fn.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.webp')):
                    self.paths.append(os.path.join(fold_dir, fn))
        self.transform = transform
        # if ckpt is binary, record indices for mapping when saving/analysis
        self.ckpt_classes = list(ckpt_classes) if ckpt_classes is not None else None

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        p = self.paths[idx]
        img = Image.open(p).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, p

# %%
# Section 8 — Build datasets and dataloaders
BATCH_SIZE = 32
NUM_WORKERS = 0

# Combine train/val/test for food dataset using folds
FOLDS = ['train', 'val', 'test']
food_dataset = ImageFolderFlat(SPLITS_DIR, classes, folds=FOLDS, transform=eval_tfms)
food_loader = DataLoader(food_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
print('Food dataset size (combined folds):', len(food_dataset))

# Non-food dataset: combine all folds under NON_FOOD_DIR
nonfood_dataset = NonFoodDataset(NON_FOOD_DIR, folds=FOLDS, transform=eval_tfms)
nonfood_loader = DataLoader(nonfood_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
print('Non-food dataset size (combined folds):', len(nonfood_dataset))
# Out:
# Binary checkpoint detected. Collected 43750 images from splits and labeled them as 'food' (idx=0).
# Food dataset size (combined folds): 43750
# Non-food dataset size (combined folds): 5026

# %%
# Section 9 — Inference helper
import math

# Determine if checkpoint is binary and get food index
binary_mode, food_idx, not_food_idx = _detect_binary_food_ckpt(classes)
if binary_mode:
    print(f"Binary model detected. food_idx={food_idx}, not_food_idx={not_food_idx}")

def run_inference(model, loader, device, topk=5):
    """Run inference.

    For binary models (food vs not_food) returns per-image dict with 'path', 'gt_idx', 'food_prob' and 'pred_label'.
    For multi-class models returns 'topk' as before.
    """
    results = []
    model.to(device)
    model.eval()
    with torch.no_grad():
        for batch in loader:
            # batch may be (imgs, labels, paths) or (imgs, paths)
            if len(batch) == 3:
                imgs, labels, paths = batch
            else:
                imgs, paths = batch
                labels = [None] * len(paths)
            imgs = imgs.to(device)
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            for i in range(probs.shape[0]):
                row = probs[i]
                if binary_mode:
                    # use food index probability
                    food_probability = float(row[food_idx])
                    pred_label = classes[int(row.argmax())]
                    results.append({
                        'path': paths[i],
                        'gt_idx': int(labels[i]) if labels is not None and labels[i] is not None else None,
                        'food_prob': food_probability,
                        'pred_label': pred_label,
                    })
                else:
                    top_idx = row.argsort()[-topk:][::-1]
                    top_probs = row[top_idx]
                    top_classes = [classes[j] for j in top_idx]
                    results.append({
                        'path': paths[i],
                        'gt_idx': int(labels[i]) if labels is not None and labels[i] is not None else None,
                        'topk': list(zip(top_classes, [float(x) for x in top_probs]))
                    })
    return results
# Out:
# Binary model detected. food_idx=0, not_food_idx=1

# %%
# Section 10 — Run inference on food dataset and compute metrics
CONF_THRESH = 0.7

food_results = run_inference(model, food_loader, device, topk=5)

if binary_mode:
    # For binary model we expect all food_dataset samples to be positive (we labeled them as food_idx)
    total_food = len(food_results)
    detected_food = 0
    missed_food = []
    food_probs = []
    for r in food_results:
        prob = r.get('food_prob', 0.0)
        food_probs.append(prob)
        if prob >= CONF_THRESH:
            detected_food += 1
        else:
            missed_food.append(r['path'])
    tpr = detected_food / total_food if total_food else 0.0
    print(f'Food detection on combined folds: {total_food} images. Detected (>= {CONF_THRESH}): {detected_food}. TPR: {tpr:.4f}')
    print(f'Collected {len(missed_food)} missed food images (prob < {CONF_THRESH})')
    # Prepare bad_images_by_class-like structure for compatibility (single key 'food')
    bad_images_by_class = {'food': missed_food}
    # Optionally save distribution stats
    import statistics
    print('Food prob mean:', statistics.mean(food_probs) if food_probs else 0.0)
    print('Food prob median:', statistics.median(food_probs) if food_probs else 0.0)
else:
    # Multiclass path (unchanged)
    correct1 = 0
    correct5 = 0
    bad_images_by_class = {}
    for r in food_results:
        gt = r['gt_idx']
        topk = r['topk']  # list of (class_name, prob)
        top_classes = [t[0] for t in topk]
        top_probs = [t[1] for t in topk]
        # top1
        if gt is not None and classes[gt] == top_classes[0]:
            correct1 += 1
        # top5
        if gt is not None and classes[gt] in top_classes:
            correct5 += 1
            idx = top_classes.index(classes[gt])
            if top_probs[idx] < CONF_THRESH:
                bad_images_by_class.setdefault(classes[gt], []).append(r['path'])
        else:
            # GT not in top5
            bad_images_by_class.setdefault(classes[gt] if gt is not None else 'UNKNOWN', []).append(r['path'])

    n = len(food_results)
    acc1 = correct1 / n if n else 0.0
    acc5 = correct5 / n if n else 0.0
    print(f'Food dataset: {n} images. Top-1 acc: {acc1:.4f}, Top-5 acc: {acc5:.4f}')
    print('Bad images (per-class counts):')
    for k,v in bad_images_by_class.items():
        print(k, len(v))
# Out:
# Food detection on combined folds: 43750 images. Detected (>= 0.7): 42224. TPR: 0.9651
# Collected 1526 missed food images (prob < 0.7)
# Food prob mean: 0.966616387503078
# Food prob median: 0.9995938539505005

# %%
# Section 11 — Run inference on non-food and flag confident predictions
import shutil

non_food_flagged = []
model.to(device)
model.eval()
with torch.no_grad():
    for imgs, paths in nonfood_loader:
        imgs = imgs.to(device)
        logits = model(imgs)
        probs = torch.softmax(logits, dim=1).cpu().numpy()
        for i in range(probs.shape[0]):
            row = probs[i]
            if binary_mode:
                food_probability = float(row[food_idx])
                pred_label = classes[int(row.argmax())]
                # All images in this dataset are expected to be NOT food (ground-truth = not_food_idx)
                gt_idx = not_food_idx
                if food_probability >= CONF_THRESH:
                    # false positive: non-food image predicted as food with high confidence
                    non_food_flagged.append({
                        'path': paths[i],
                        'food_prob': food_probability,
                        'pred_label': pred_label,
                        'gt_idx': gt_idx,
                    })
            else:
                max_idx = int(row.argmax())
                max_prob = float(row[max_idx])
                if max_prob >= CONF_THRESH:
                    non_food_flagged.append({
                        'path': paths[i],
                        'pred_class': classes[max_idx],
                        'prob': max_prob,
                        'gt_idx': None,
                    })

# Compute non-food metrics: total, false positives, true negatives, FPR, specificity
total_nonfood = len(nonfood_dataset)
false_positives = len(non_food_flagged)
true_negatives = total_nonfood - false_positives
fpr = false_positives / total_nonfood if total_nonfood else 0.0
specificity = true_negatives / total_nonfood if total_nonfood else 0.0
print('Non-food images total:', total_nonfood)
print('Non-food images flagged (confident predictions / false positives):', false_positives)
print(f'False positive rate (FPR): {fpr:.4f}  | Specificity (TN / N): {specificity:.4f}')
# Out:
# Non-food images total: 5026
# Non-food images flagged (confident predictions / false positives): 17
# False positive rate (FPR): 0.0034  | Specificity (TN / N): 0.9966

# %%
# Section 12 — Save results and optionally copy flagged images
bad_json = os.path.join(OUTPUT_DIR, 'bad_images_by_class.json')
nonfood_json = os.path.join(OUTPUT_DIR, 'non_food_confident.json')

with open(bad_json, 'w') as f:
    json.dump(bad_images_by_class, f, indent=2)
with open(nonfood_json, 'w') as f:
    json.dump(non_food_flagged, f, indent=2)

print('Saved:', bad_json)
print('Saved:', nonfood_json)

COPY_FLAGGED = True
if COPY_FLAGGED:
    bad_out_dir = os.path.join(OUTPUT_DIR, 'bad_images_by_class')
    nonfood_out_dir = os.path.join(OUTPUT_DIR, 'non_food_confident')
    os.makedirs(bad_out_dir, exist_ok=True)
    os.makedirs(nonfood_out_dir, exist_ok=True)
    # copy non-food
    for item in non_food_flagged:
        dst = os.path.join(nonfood_out_dir, os.path.basename(item['path']))
        try:
            shutil.copy(item['path'], dst)
        except Exception as e:
            print('Copy error:', e)
    # copy bad images by class
    for cls_name, paths in bad_images_by_class.items():
        cls_dir = os.path.join(bad_out_dir, cls_name)
        os.makedirs(cls_dir, exist_ok=True)
        for p in paths:
            try:
                shutil.copy(p, os.path.join(cls_dir, os.path.basename(p)))
            except Exception as e:
                print('Copy error:', e)
    print('Flagged images copied to:', bad_out_dir, 'and', nonfood_out_dir)
# Out:
# Saved: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class.json
# Saved: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.json
# Flagged images copied to: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class and d:\VSC FILES\testtrain\inference_outputs\non_food_confident

# %%
# Section 13 — Summary & quick checks
print('\nSummary:')
print('Food images total:', len(food_dataset))
print('Non-food images total:', len(nonfood_dataset))

# Print appropriate metrics depending on model type
if binary_mode:
    if 'tpr' in globals():
        print(f'Detected (TPR) at threshold {CONF_THRESH}:', f"{detected_food}/{total_food} = {tpr:.4f}")
    else:
        print('Run Section 10 to compute detection metrics (TPR).')
    # Non-food metrics (if computed)
    if 'total_nonfood' in globals():
        print(f'Non-food: Total={total_nonfood}, False positives={false_positives}, FPR={fpr:.4f}, Specificity={specificity:.4f}')
    else:
        print('Run Section 11/11.5 to compute non-food false positive metrics.')
else:
    # multiclass metrics
    if 'acc1' in globals() and 'acc5' in globals():
        print('Top-1 acc:', acc1)
        print('Top-5 acc:', acc5)
    else:
        print('Run Section 10 to compute multiclass accuracy metrics.')

print('Bad images saved to:', bad_json)
print('Non-food flagged saved to:', nonfood_json)

# Quick sanity checks
if not os.path.exists(bad_json):
    print('Warning: bad_images JSON missing')
if not os.path.exists(nonfood_json):
    print('Warning: non-food JSON missing')

print('\nDone.')
# Out:
# Summary:
# Food images total: 43750
# Non-food images total: 5026
# Detected (TPR) at threshold 0.7: 42224/43750 = 0.9651
# Non-food: Total=5026, False positives=17, FPR=0.0034, Specificity=0.9966
# Bad images saved to: d:\VSC FILES\testtrain\inference_outputs\bad_images_by_class.json
# Non-food flagged saved to: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.json
#
# Done.

# %%
# Section 12.5 — List images below confidence threshold
# Shows all food images (from splits) where food probability < CONF_THRESH
print(f"Listing images with food probability < {CONF_THRESH}:\n")
if binary_mode:
    low_conf = bad_images_by_class.get('food', [])
    print(f'Found {len(low_conf)} food images below {CONF_THRESH}\n')
    # print full paths; if many, show first 200 to avoid flooding
    max_show = 10000
    for i, p in enumerate(low_conf):
        if i >= max_show:
            print(f"... ({len(low_conf)-max_show} more) ...")
            break
        print(p)
else:
    # For multiclass models, bad_images_by_class already collects low-confidence/misranked images
    total = 0
    for cls, paths in bad_images_by_class.items():
        print(f"Class: {cls} -> {len(paths)} images")
        total += len(paths)
        for p in paths[:200]:
            print(p)
    print(f"Total low-confidence images across classes: {total}")
# Out:
# Listing images with food probability < 0.7:
#
# Found 1526 food images below 0.7
#
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_189.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\train\adobong_pusit_45.jpg
# D:\VSC FILES\testtrain\splits_new_v2\adobong_pusit\test\adobong_pusit_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\0ea680ca1fd3b77b9aa557639dbe707c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\1931c66d1b086e340fa52b2bcc245f80.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\1e9001e43ed7869785b1c0baa371aac3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\282a61f6aa0f51877c4f1b5a197e004d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\2c31e25f7b81ecbdee6e3cfc2e0cc434.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\33443ec9639b4936397323e994762349.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\439abc048e795d9648a74ceac49c7981.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\481963004_664273776280208_7664356395790776002_n.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\5287ee0bffc2e0a069952f58986ccad9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\57aa44bf6c3a49796cbad861190284d9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\629936c8f9b2a537b9532a5ae3848861.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\66299a3522df59bfad9c06d5a2578052.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\794501afdf95882bf8d52ea7b4da7ada.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\7c4b360cbc4499b7a5919c93fb431205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\93ec548afcfb54067c34ee8f7c34ab6f.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\96d62e654942faaa18cb162d0b364f53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\a952b3d369c29c0f22cd5f27a6c20d4d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\ad3ef9e418bf73e404d99ff052d9e950.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\ad440d76162ef895ecedaf45a9b21fc5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_141.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_191.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_315.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_326.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\apple_340.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\b4cc84fe489b51a0e7c0b918292cee1a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\bbaf81f886628bf819fbc76bf4936dae.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\be20ce3f5ddf893fa64fa9b7dccab826.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\cac7f7750e3301cd7c6e2a0bbeb1e53a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\cb7dec1f207c8c2fcabe29ac14bd67fb.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\d23334ad46644d1cf56b560a6882023a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\Screenshot 2025-11-13 162948.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\Screenshot 2025-11-13 163019.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\Screenshot 2025-11-13 163140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000002.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000008.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000011.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000013.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000018.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000022 (1).jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000022.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000023.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000025.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000032.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000035.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000040.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000046.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000047.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000050 (2).jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000052.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000059.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000061.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000064.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000065.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000068.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000069.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000070.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000074.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000077.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000078.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000085.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000087.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_apple_fruit_000088.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000101 (1).jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000101 (2).jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000171.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\train\unsplash_sliced_apples_000182.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000091.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000096.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000099.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000108.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000114.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000118.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000139.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_apple_fruit_000147.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_sliced_apples_000005.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\val\unsplash_sliced_apples_000029.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\08_bab498672f1721e96dca5cdc659876ce.jpg.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\12_0a30abc7f0e3da3b38b4f7830f5bff0c.jpg.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\16_8257b98f9d4b41623b1b30f56f1d8fa9.jpg.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\17_b443c83c2aaa170afba24dbc5e75a161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\19_55b3ca9346b622fada2a5795d6608774.jpg.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\20_ca61ef0c2b600b105e09d66268378d73.jpg
# D:\VSC FILES\testtrain\splits_new_v2\apple\test\7d949f7b28222d9aa6977d7fed00fe12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\arroz_caldo\val\arroz_caldo_324.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baby_back_ribs\train\baby_back_ribs_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_295.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_337.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_360.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_363.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_390.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\train\baked_tahong_477.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\val\baked_tahong_581.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\test\baked_tahong_472.jpg
# D:\VSC FILES\testtrain\splits_new_v2\baked_tahong\test\baked_tahong_518.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut-nedir.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_106.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_366.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_378.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_394.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_455.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_52.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_550.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_647.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_654.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_81.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\balut_86.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\intro-1705686781.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\Screenshot 2025-08-17 100045.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\train\Screenshot 2025-08-17 100901.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\balut_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\val\Screenshot 2025-08-17 153259.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\test\balut_115.jpg
# D:\VSC FILES\testtrain\splits_new_v2\balut\test\balut_498.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\020486861b1bc03a2fc52f6b4e548512.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\02121ccd7ff8733a4816521bd4ea0ff5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\02fd45f0f159ab6076537e50b91ebecc.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\046fd4f956091f493acb92bb0820c6d1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\0913aa99520c04ce736098ead85cfecc.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\09cec7be6399702a3e2ddd51b86c536a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\0abd28b79ed8ba55789292ea64555175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\0c1823e296c3faeb35ef3ae96be0a103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\0cd2d035af0bb1ef839fe342cb7ba3e3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\113ca1410f73c3e8e4fa02e7077a0c89.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\12265972f9a08d906bcd203c718f5bcf.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\128af0f455cc9b086e6613c913cf22cf.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\13aaf6333984ccca902e13be6fbe66ab.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\15f1d82375dbaa3f309b7163b141a6fc.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\16c5b0e2743bea00a822d3468dd9890e.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\1754e15c73a0c333a75ba6e41b5f0d16.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\1918115f629e06213368eecde80d350c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\19d3342462f80d8e241bb01e13c2c671.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\1afcb9dab4d7ada4a34476848b35b5b9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\1b7a11033720ec315b76b62daf48b415.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\1ddb9a73e0bf2228076f8b63297dce82.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\210d0e27b3fcaede2c07fd9ed6613947.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\22f81d1e1df6302e8c14ac2c79061c85.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\24f6d2cac5b177f27b2b65257ba63f53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\294e6c9344d604a14c303af11bcac5b9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\2a9c22f2d9eec5c59cf3666222d890e3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\2d6c468dbb22ce5956779995676a32a5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\2d8a16e53b6e050493d6d665e38af665.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\2f00ca09a7536c90d6e1d2f292df676c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\315c37dc32eaa7ea9102e758a8d5d019.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\32c78540c35e3b93343bf07edf851df6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\334dce144394a55b1c219ea5d10e3f7d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\381d31de982841b08893c7b12a54d2b8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\3a2ae23df4353a5917baa3581ee3beb7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\3c092626aae3a0f58806a6c4d9bf6250.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\3ce31136332c789742a155478b283dfb.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\3e9c456be3cddac9f0c9fe8c6c458b26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\40f4d5c12f6f597f7222f6d474f93170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\41d0c5867823403742db71fdfdfb3c35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\43620004ad5fea1a5732b31eaba8aaa4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\439c0be3007c12521703ef0720abf0e0.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4619880af2010c1fc512123ececdda83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\461fa169807b0983340723d11aad17d7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\46b5745de414dedf7982bbb113170fe6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\48bc34a3ff45a895d84560de0ad8cabf.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4909434e563f84fcaf904c0ef57a87a5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\49b07e6a38dbb5bc78a022f909281e6b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4d07b07464c06f8f8dac1c57104a20b7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4e0eecf213db9046e83ff9ed1573b251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4f1d4be0e466e6170177e660ef027647.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\4fdd3a7377fbede052c20231370622c2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\514422738_10111850614230917_1411817788005807042_n.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\51W9iO9AwhL.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\53cc287aa137ebf0f04a3b75666232e4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\54809966fbe9cfa68d1db998ee401045.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\550px-nowatermark-Peel-a-Banana-Step-2-Version-5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\55220942bd37b6971923f331cc033ffd.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\5c65e89d10bef0f634e01202ff924aa9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\5c96d50c3f51de17e7252aa55b185b44.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\5d3390c4bb236cdb65c3e8e79cdb4393.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\616f0b1dfa63284895f5216877d4516c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\61c5879f704bc68184b96650dfbb4d36.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\6453378cd39df63a45788b99a9bfe45a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\64b5ba1410265d9677f934b902fa6265.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\664de2c93ae2888b55b9fc734ea1e1d8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\67fdde9faaa64d11c2b910d61ea335f7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\6cafc1804a2de16c26b64e51aa12075b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\6df9dc9aac4b0f6652282b2da0748038.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\6f04075c727742493938f3da72d6fa85.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\6f4013c36a135dc48ce209e43bf10228.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\732ccf199e14f46df280599fe68fe81d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\74044619a72dda69830977f30712fd93.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\742bf4d00d8b89cc2e2462120dc15251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\744a74b7bd5d525a35e0d12c991c25be.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\78ddb43bee1cdffc49f4e66397f89c09.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\795f890bdd5c64c14835b36833e98337.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\7d17ff1cf9cc376d5f58eade2a924810.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\7de6aa81c34364b66ce82320d68f1117.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\80dcdec4f511542e59f587572c054813.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\828ac6cc2da46be700c7eb6a81800ea1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\83f5ef62627393af816a547ff25555c3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\848ad4cbd82e93f5729f692dd60a9c50.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\85da745889a81af1eb47294938022a92.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\861b4bc92d9c53bdd5ccb51b048f3af1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\898092af5cd076306011774c9c1c89fc.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\8ac35e43274cd5a3c8f03f2a8a353493.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\8f6cbba41e42367bdf6f7e693570d54e.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\923fb7a9621eccd37676b46256f19a64.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\93a3d0072ccf4824abe4285a8178cd29.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\962049e8c90033a7bbac476790703cd1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\968ebdb7532edd1729d20887c6c5d1c8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\971b9e028e3e5ea1368d28e08cc78552.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\982459e55647d49c5bae9623a6e94ed8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9a1d104fea5cfeee0dc3fb7fed860a4d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9b6609b6d113c46b591a8d912b3acc61.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9cc633b0fdc9b7cbf5154d148995b311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9d3da6c0066ea641e1836fc5c34f122b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9f13875d60278fca5404aa031ce8148e.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\9f1aa341add0a3fc0399d404a7322146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a4f4fdf8fd5fa302810ae703124b52d1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a57b442f89a3f7567f770ab24d717186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a6e84f1fed47880ea61ee0d64f97b101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a79726efada4cfa066cf7fa05ed26e4b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a893d5cb47aae9d7ac04c76036dc45df.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a8b039ddd74088f1a3013daadaeaf555.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\a8e53a73d439e727fa7be61e6f2b5f06.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ab655eb82cccfa445a103c6073c8638d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\acff9dcbb83ea5b1a1baaed39f6ef583.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ad23b07b9d8cfe37a6d738d4ba2b6063.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\af7cfcfaecbac794b53897c3bf074de6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\b0b4a5383492eea3204d1e1ebbaaf5e3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\b2685af22690c80e459b7daaaa16a969.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\b84662311030e675bfe8a00b5f56f403.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\bd2aa0fad1941427ec096577e65eb803.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\be32224e364f798f5ce96574bdd5e4f5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\bfa6f19b1c47c629338f65a2c2eb9ac4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\c178dc6435ef8c23edf4c6973df63907.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\c591727aa56bd5c71e37e9f5d606a5e1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\c6d63355980a650d4f50d2618a0b0156.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\c781fe40551e16392f8994895067a02a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ca748abb4306271e14a26f0776f4b85b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\cba583d453c45626ce48b12f6962847f.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ccce22240493a87ce5e1d30b71229254.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\cf92ac3d7fdcf484b0df3fcf40fd40ed.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\d65a87753e92b2c3e13748499a884f9f.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\d6fb1d07ffbd425c73449052f3aa2c86.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\d809d4559209f6896a03765486825b5c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\d80ea27a21643b4fa881b415f2c30eaf.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\df702c867d356d6d28e0367a2b336fe4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e2d5e47654bdc12e68f0142295e38ae1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e4cbc47f67f989ef57a76442be0c4deb.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e55cb9b6e4b2afe70f754d5d9c8b2d6c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e734e3cc776a604d99f380670414a3d6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e7e9800c97d3c604c8095ba3698e53c8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\e9cebf85bd81b81bf34f6e8cf5c66d62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\edb2a900b49a90cdc6a9d19b58e7d6b0.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\edb33692ab462c9aaaf61270fe6ee8bc.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\edc50c47ba50baf36988df1c08788d22.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ee76e500bcae71f679aaa18085d7c9a2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f2c628dbaeb221329eb5340da9c7f44d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f2c6691a0a3b4a668f4e46511e831f70.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f435e9a4d02b0334912f83fb666cecaf.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f5ef90a52dc04802f9f75f33e153ca4e.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f795d16147d40a070ccb3b95e7042252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\f7df40c1d294da14caaeadf61549f4f1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\fc81f8559be3a208fe1361574194be47.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\fd53119e0cda90f25e22c8dff99e540c.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\fe6043ab518fce5c66a544e9caa15a88.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\ff15c4e67ebd2dae4bbb1d1213b42642.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\GettyImages-1393251380-7aa817086d404179bfa7e53968c445e4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images (1).jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images (2).jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images (3).jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images (5).jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images (6).jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\images.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132029.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132035.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132049.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132053.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132057.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132059.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132105.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132118.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132120.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132122.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132129.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\IMG_20251113_132132.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\pngtree-bunch-of-ripe-yellow-bananas-fruit-banana-fruit-plenty-photo-image_28799540.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\pngtree-ripe-bananas-ligament-large-ripe-and-fragrant-bananas-on-wooden-background-picture-image_2817328.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\Ripe_latundan_bananas.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\Screenshot 2025-11-13 225014.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\Screenshot 2025-11-13 232936.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\shutterstock_225197908-660x439.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000001.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000006.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000007.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000008.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000010.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000019.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000021.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000028.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000030.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000037.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000042.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000147.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\train\unsplash_banana_000698.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\066086ad5eae39540a61785d4149e629.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\109111fad35e02d67b083c4af243141b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\28b6a601b955ec26575999399960458b.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\2e0676c039075180e93e62147a0d174e.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\5d67823006105ad32e622bffa7d3af3d.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\5f241e2a36e05fdf9377f41c1152fbb6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\718968d3a5d07616770fd1cb7d5ae858.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\731713dc93f50823785ec3d0a6e50392.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\763377e4773cb029b810ebaa9d1c913a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\7c531dd3e08a0db02bd1eb0a2803d5e2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\8078d8fef7816b984755d46063e691c5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\81346b485de2dc9107c71464736985aa.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\8235ecfd4f1dfcc3e9d84dc3c4bb97b1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\8270ee6945021b643499d319d5c1ecea.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\9817f9a31b0870c4d8f339335f53ee2a.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000164.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000167.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000251.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000336.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000338.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000377.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\val\unsplash_banana_000506.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\80516521643fda97c96e014fd647a9f3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\9052864dfba0adbbf5c7f6d8511cc1df.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000009.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000044.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000047.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000050.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000061.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000065.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000067.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000074.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000081.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000082.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000085.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000093.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000094.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000096.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000097.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000098.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000105.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000120.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000121.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000126.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000129.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000145.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000222.jpg
# D:\VSC FILES\testtrain\splits_new_v2\banana\test\unsplash_banana_000240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_192.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\train\beef_bistek_340.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_bistek\test\beef_bistek_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_kaldereta\train\beef_kaldereta_250.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_146.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_18.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_271.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\train\beef_tartare_272.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\val\beef_tartare_140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beef_tartare\test\beef_tartare_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_167.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_171.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_235.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_260.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_340.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\train\beignets_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_151.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_187.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\val\beignets_28.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\test\beignets_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\beignets\test\beignets_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_335.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bibimbap\train\bibimbap_84.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_1.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_114.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_153.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_168.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_22.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_23.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_237.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_25.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_260.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_264.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_298.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_303.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_310.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_330.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_61.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_68.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_73.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_80.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\train\biko_96.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\val\biko_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\val\biko_50.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\test\biko_28.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\test\biko_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\biko\test\biko_92.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_139.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_157.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_169.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_186.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_273.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_285.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_50.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_54.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\train\boiled_egg_8.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\val\boiled_egg_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\test\boiled_egg_315.jpg
# D:\VSC FILES\testtrain\splits_new_v2\boiled_egg\test\boiled_egg_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bread_pudding\train\bread_pudding_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bread_pudding\train\bread_pudding_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\bread_pudding\train\bread_pudding_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\train\caesar_salad_296.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\train\caesar_salad_74.jpg
# D:\VSC FILES\testtrain\splits_new_v2\caesar_salad\test\caesar_salad_311.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_158.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_200.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_265.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_275.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\train\cannoli_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\val\cannoli_259.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\val\cannoli_308.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\test\cannoli_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cannoli\test\cannoli_341.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_103.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_124.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_127.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_164.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_214.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_217.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_233.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_245.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_258.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_317.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_326.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_73.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\train\cheesecake_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\val\cheesecake_140.jpg
# D:\VSC FILES\testtrain\splits_new_v2\cheesecake\val\cheesecake_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\train\chicken_curry_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\val\chicken_curry_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_curry\test\chicken_curry_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_quesadilla\train\chicken_quesadilla_275.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_quesadilla\test\chicken_quesadilla_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_284.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chicken_wings\train\chicken_wings_316.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_12.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_120.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_14.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_141.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_168.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_170.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_173.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_180.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_189.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_195.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_229.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_230.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_231.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_242.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_250.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_278.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_282.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_291.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_299.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_300.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_307.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_309.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_320.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_328.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_334.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_4.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_81.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_82.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\train\chocolate_cake_83.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\val\chocolate_cake_255.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\val\chocolate_cake_29.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_234.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_cake\test\chocolate_cake_51.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_110.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_132.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_139.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_193.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_222.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_224.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_225.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_243.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_247.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_269.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_282.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_287.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_30.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_301.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_32.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_337.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_338.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_66.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_72.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\train\chocolate_mousse_86.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_188.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_58.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\val\chocolate_mousse_9.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\test\chocolate_mousse_2.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\test\chocolate_mousse_234.jpg
# D:\VSC FILES\testtrain\splits_new_v2\chocolate_mousse\test\chocolate_mousse_51.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_106.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_11.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_125.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_149.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_162.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_172.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_180.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_195.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_271.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_298.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_30.jpg
# D:\VSC FILES\testtrain\splits_new_v2\churros\train\churros_301.jpg
# ...
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_365.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\train\puto_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\val\puto_107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\puto\val\puto_334.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_165.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_284.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\train\ramen_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\ramen\test\ramen_341.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_126.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_135.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_160.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_182.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_199.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_200.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_205.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_215.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_220.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_223.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_257.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_286.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_45.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_71.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\train\red_velvet_cake_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\val\red_velvet_cake_308.jpg
# D:\VSC FILES\testtrain\splits_new_v2\red_velvet_cake\test\red_velvet_cake_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_348.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\train\samosa_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\val\samosa_332.jpg
# D:\VSC FILES\testtrain\splits_new_v2\samosa\val\samosa_57.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_115.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_128.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_136.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_147.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_176.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_182.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_19.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_204.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_211.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_212.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_219.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_227.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_278.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_292.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_305.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_321.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_34.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_350.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_48.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\train\sashimi_62.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\val\sashimi_20.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\val\sashimi_255.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_175.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sashimi\test\sashimi_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_163.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_209.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_24.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\train\sausage_32.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sausage\val\sausage_3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\scallops\train\scallops_254.jpg
# D:\VSC FILES\testtrain\splits_new_v2\shrimp_sinigang\val\shrimp_sinigang_15.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_174.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_254.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\train\sipo_egg_63.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sipo_egg\test\sipo_egg_270.jpg
# D:\VSC FILES\testtrain\splits_new_v2\spaghetti_bolognese\test\spaghetti_bolognese_90.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\train\steak_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\val\steak_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\steak\test\steak_202.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_10.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_102.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_126.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_14.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_148.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_158.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_16.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_171.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_185.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_23.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_276.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_278.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_31.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_346.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_350.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_59.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_6.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\train\strawberry_95.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\val\strawberry_21.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\val\strawberry_3.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\val\strawberry_5.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\val\strawberry_89.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\test\strawberry_266.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry\test\strawberry_51.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_163.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_314.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_34.jpg
# D:\VSC FILES\testtrain\splits_new_v2\strawberry_shortcake\train\strawberry_shortcake_94.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sunny_side_up\train\sunny_side_up_201.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sunny_side_up\train\sunny_side_up_289.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_116.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_122.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_19.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_194.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_273.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_290.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_344.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_346.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\train\sushi_53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\val\sushi_152.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\val\sushi_332.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_178.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_264.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_288.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_46.jpg
# D:\VSC FILES\testtrain\splits_new_v2\sushi\test\sushi_49.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_239.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\train\tacos_47.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tacos\val\tacos_241.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_290.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_328.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_342.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_369.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\train\taho_370.jpg
# D:\VSC FILES\testtrain\splits_new_v2\taho\val\taho_331.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_222.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_281.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_282.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_329.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_39.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\train\takoyaki_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\val\takoyaki_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\takoyaki\test\takoyaki_315.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tapsilog\train\tapsilog_358.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tempura\train\tempura_164.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tempura\train\tempura_271.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_112.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_119.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_128.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_138.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_198.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_213.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_252.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_26.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_36.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\train\tiramisu_74.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_142.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_197.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_267.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tiramisu\test\tiramisu_280.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_13.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_184.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_199.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_268.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_313.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_345.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\train\tuyo_7.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\val\tuyo_332.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\test\tuyo_123.jpg
# D:\VSC FILES\testtrain\splits_new_v2\tuyo\test\tuyo_56.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_109.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_192.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_206.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_240.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_261.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\train\waffles_318.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\val\waffles_159.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\val\waffles_75.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\test\waffles_319.jpg
# D:\VSC FILES\testtrain\splits_new_v2\waffles\test\waffles_49.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_104.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_107.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_129.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_131.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_150.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_155.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_157.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_161.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_162.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_166.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_179.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_181.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_227.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_238.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_243.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_35.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_38.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_40.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_42.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_43.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_44.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_53.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_55.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_60.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_65.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_67.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_97.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\train\white_rice_98.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\val\white_rice_226.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\val\white_rice_241.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_101.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_262.jpg
# D:\VSC FILES\testtrain\splits_new_v2\white_rice\test\white_rice_339.jpg

# %%
# Section 11.5 — Ensure non-food inference ran and list flagged non-food images
import csv

# If non_food_flagged isn't defined, run the non-food inference loop now
if 'non_food_flagged' not in globals():
    non_food_flagged = []
    model.to(device)
    model.eval()
    with torch.no_grad():
        for imgs, paths in nonfood_loader:
            imgs = imgs.to(device)
            logits = model(imgs)
            probs = torch.softmax(logits, dim=1).cpu().numpy()
            for i in range(probs.shape[0]):
                row = probs[i]
                if binary_mode:
                    food_probability = float(row[food_idx])
                    pred_label = classes[int(row.argmax())]
                    gt_idx = not_food_idx
                    if food_probability >= CONF_THRESH:
                        non_food_flagged.append({
                            'path': paths[i],
                            'food_prob': food_probability,
                            'pred_label': pred_label,
                            'gt_idx': gt_idx,
                        })
                else:
                    max_idx = int(row.argmax())
                    max_prob = float(row[max_idx])
                    if max_prob >= CONF_THRESH:
                        non_food_flagged.append({
                            'path': paths[i],
                            'pred_class': classes[max_idx],
                            'prob': max_prob,
                            'gt_idx': None,
                        })

# Recompute non-food summary metrics if they don't exist
total_nonfood = len(nonfood_dataset)
false_positives = len(non_food_flagged)
true_negatives = total_nonfood - false_positives
fpr = false_positives / total_nonfood if total_nonfood else 0.0
specificity = true_negatives / total_nonfood if total_nonfood else 0.0
print('Non-food images flagged (confident predictions):', false_positives)

# Save CSV with results for easier review
csv_path = os.path.join(OUTPUT_DIR, 'non_food_confident.csv')
with open(csv_path, 'w', newline='', encoding='utf-8') as cf:
    if binary_mode:
        fieldnames = ['path','food_prob','pred_label','gt_idx']
    else:
        fieldnames = ['path','pred_class','prob','gt_idx']
    writer = csv.DictWriter(cf, fieldnames=fieldnames)
    writer.writeheader()
    for item in non_food_flagged:
        writer.writerow(item)
print('Saved non-food flagged CSV to:', csv_path)

# Print first 200 flagged examples (or fewer) for quick inspection
for i, item in enumerate(non_food_flagged[:200]):
    if binary_mode:
        print(i+1, item['path'], f"food_prob={item['food_prob']:.3f}", 'pred=', item.get('pred_label'), 'gt_idx=', item.get('gt_idx'))
    else:
        print(i+1, item['path'], item.get('prob'), item.get('pred_class'))

print(f'Non-food summary -> Total: {total_nonfood}, False positives: {false_positives}, FPR: {fpr:.4f}, Specificity: {specificity:.4f}')

# Optionally copy these flagged non-food images to output folder (already done in Section 12 if COPY_FLAGGED)
if not COPY_FLAGGED:
    print('\nTo copy flagged images to disk, set COPY_FLAGGED = True and re-run Section 12.')
# Out:
# Non-food images flagged (confident predictions): 17
# Saved non-food flagged CSV to: d:\VSC FILES\testtrain\inference_outputs\non_food_confident.csv
# 1 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000041_P8230123.jpg food_prob=0.987 pred= food gt_idx= 1
# 2 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000232_non_food_000710.jpg food_prob=0.831 pred= food gt_idx= 1
# 3 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000246_non_food_001108.jpg food_prob=0.893 pred= food gt_idx= 1
# 4 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000272_non_food_001379.jpg food_prob=0.788 pred= food gt_idx= 1
# 5 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000313_IMG_20220603_175735.jpg food_prob=1.000 pred= food gt_idx= 1
# 6 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000650_IMG20230211200421.jpg food_prob=0.831 pred= food gt_idx= 1
# 7 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\000791_100_2896.jpg food_prob=0.922 pred= food gt_idx= 1
# 8 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\001328_fefea57d65ac52136f2e55a13e1ad17f.jpg food_prob=1.000 pred= food gt_idx= 1
# 9 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\001474_IMG_20220603_175729.jpg food_prob=1.000 pred= food gt_idx= 1
# 10 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\001638_035_00ab013df807076845bbec553e9b41d9.jpg.jpg food_prob=0.938 pred= food gt_idx= 1
# 11 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\002355_non_food_000378.jpg food_prob=0.820 pred= food gt_idx= 1
# 12 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003188_P6170119.jpg food_prob=0.736 pred= food gt_idx= 1
# 13 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003236_dc23e5f78586a6916564c1c54f1d46ad.jpg.jpg food_prob=0.996 pred= food gt_idx= 1
# 14 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003530_514267266_25378001535137666_1063305567482256627_n.jpg food_prob=1.000 pred= food gt_idx= 1
# 15 D:\VSC FILES\testtrain\food_not_food_ds\not_food\train\003768_non_food_001331.jpg food_prob=1.000 pred= food gt_idx= 1
# 16 D:\VSC FILES\testtrain\food_not_food_ds\not_food\val\000498_c561c2a77d5b9b03702efc423b18cb9a.jpg food_prob=0.761 pred= food gt_idx= 1
# 17 D:\VSC FILES\testtrain\food_not_food_ds\not_food\test\000017_123_da47b22102623a9f809aa3a98987717c.jpg.jpg food_prob=0.996 pred= food gt_idx= 1
# Non-food summary -> Total: 5026, False positives: 17, FPR: 0.0034, Specificity: 0.9966
